# %% [markdown]
# ## Kinetics700

# %%
# import tensorflow as tf
# import os

# def load_dataset(data_dir, batch_size=32, num_frames=32, frame_height=224, frame_width=224):
#     # Define the file pattern to match the dataset files.
#     file_pattern = os.path.join(data_dir, '*/*.tfrecord')
    
#     # Create a list of dataset files.
#     file_list = tf.data.Dataset.list_files(file_pattern)
    
#     # Load and preprocess the dataset files.
#     dataset = file_list.interleave(tf.data.TFRecordDataset, num_parallel_calls=tf.data.AUTOTUNE)
    
#     # Parse the dataset records.
#     feature_description = {
#         'id': tf.io.FixedLenFeature([], tf.string),
#         'label': tf.io.FixedLenFeature([], tf.int64),
#         'rgb': tf.io.FixedLenFeature([], tf.string),
#         'num_frames': tf.io.FixedLenFeature([], tf.int64),
#     }
    
#     def parse_record(record):
#         parsed = tf.io.parse_single_example(record, feature_description)
#         id = parsed['id']
#         label = parsed['label']
#         rgb = tf.io.decode_raw(parsed['rgb'], tf.uint8)
#         num_frames = parsed['num_frames']
#         rgb = tf.reshape(rgb, [num_frames, frame_height, frame_width, 3])
#         rgb = tf.image.resize(rgb, [num_frames, frame_height, frame_width])
#         rgb = tf.image.convert_image_dtype(rgb, tf.float32)
#         rgb = tf.image.per_image_standardization(rgb)
#         rgb = tf.image.random_crop(rgb, [num_frames, num_frames, 3])
#         rgb = tf.transpose(rgb, [1, 0, 2])
#         return rgb, label
    
#     dataset = dataset.map(parse_record, num_parallel_calls=tf.data.AUTOTUNE)
    
#     # Shuffle and batch the dataset.
#     dataset = dataset.shuffle(buffer_size=10000)
#     dataset = dataset.batch(batch_size)
#     dataset = dataset.prefetch(buffer_size=tf.data.AUTOTUNE)
    
#     return dataset

# %%
# data_dir = '/path/to/kinetics-700'
# batch_size = 32
# num_frames = 32
# frame_height = 224
# frame_width = 224

# dataset = load_dataset(data_dir, batch_size, num_frames, frame_height, frame_width)

# %%
# # Split the dataset into training and validation sets
# num_samples = sum(1 for _ in dataset)
# train_size = int(0.8 * num_samples)
# val_size = num_samples - train_size

# train_dataset = dataset.take(train_size)
# val_dataset = dataset.skip(train_size)

# # Print the number of samples in each split
# print(f'Train size: {train_size} samples')
# print(f'Validation size: {val_size} samples')

# %% [markdown]
# ## Load UCF Crime dataset

# %%
# !wget https://www.dropbox.com/sh/75v5ehq4cdg5g5g/AABJtkTnNc8LcVTfH1gE_uFoa/Anomaly-Videos-Part-1.zip?dl=1
# Out:
# --2023-03-06 03:50:09--  https://www.dropbox.com/sh/75v5ehq4cdg5g5g/AABJtkTnNc8LcVTfH1gE_uFoa/Anomaly-Videos-Part-1.zip?dl=1
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.3.18, 2620:100:6018:18::a27d:312
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.3.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /sh/dl/75v5ehq4cdg5g5g/AABJtkTnNc8LcVTfH1gE_uFoa/Anomaly-Videos-Part-1.zip [following]
# --2023-03-06 03:50:09--  https://www.dropbox.com/sh/dl/75v5ehq4cdg5g5g/AABJtkTnNc8LcVTfH1gE_uFoa/Anomaly-Videos-Part-1.zip
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc419c264aba2e3ec6a6d94adf33.dl.dropboxusercontent.com/cd/0/get/B3tMWrpZsDVjS31XTXEenlcY3iDdma02QSuJyVN6mDMiy6jb9D2wrj6W5qlPM0EBo71DeiDjmCgIfd1qYtDQm2WBTOCAHFWngp2yqsVE4CKEuAKbtbssJnw5Z4zqJc-W85hXJCdR0WEQrZMr8b6WMX2tGL1SrsrLBcjeyYL5B2fiaA/file?dl=1# [following]
# ...

# %%
# !wget https://www.dropbox.com/sh/75v5ehq4cdg5g5g/AAAbdSEUox64ZLgVAntr2WgSa/Anomaly-Videos-Part-2.zip?dl=1
# Out:
# --2023-03-06 03:51:11--  https://www.dropbox.com/sh/75v5ehq4cdg5g5g/AAAbdSEUox64ZLgVAntr2WgSa/Anomaly-Videos-Part-2.zip?dl=1
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.4.18, 2620:100:601b:18::a27d:812
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.4.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /sh/dl/75v5ehq4cdg5g5g/AAAbdSEUox64ZLgVAntr2WgSa/Anomaly-Videos-Part-2.zip [following]
# --2023-03-06 03:51:11--  https://www.dropbox.com/sh/dl/75v5ehq4cdg5g5g/AAAbdSEUox64ZLgVAntr2WgSa/Anomaly-Videos-Part-2.zip
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc036e688ea06eda615f74653496.dl.dropboxusercontent.com/cd/0/get/B3v71xEdy6FsADmoYTjYjrIRuX7LeG75zWsW7-vjC2_QOjjWeJUkWQC-VefRoB8wcDBggWyD37A-GgK6cOWarUmti4PEYpOIfbHf84FbzKCwhBMUi4y9uKa62cSqKXXrCFoLTLwLTePjgtZJ0fpTvBGX3knBHqAZhlRl_16LfF9iUg/file?dl=1# [following]
# ...

# %%
# !wget https://www.dropbox.com/sh/75v5ehq4cdg5g5g/AAAgpsRNSHI_BtRnSCxxR7j9a/Anomaly-Videos-Part-3.zip?dl=1
# Out:
# --2023-03-06 03:52:17--  https://www.dropbox.com/sh/75v5ehq4cdg5g5g/AAAgpsRNSHI_BtRnSCxxR7j9a/Anomaly-Videos-Part-3.zip?dl=1
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.3.18, 2620:100:601b:18::a27d:812
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.3.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /sh/dl/75v5ehq4cdg5g5g/AAAgpsRNSHI_BtRnSCxxR7j9a/Anomaly-Videos-Part-3.zip [following]
# --2023-03-06 03:52:18--  https://www.dropbox.com/sh/dl/75v5ehq4cdg5g5g/AAAgpsRNSHI_BtRnSCxxR7j9a/Anomaly-Videos-Part-3.zip
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://ucb761dfe700c8ac5804e0507cd0.dl.dropboxusercontent.com/cd/0/get/B3uLJBAd6cdJ0MFmqKvX4Pn-qhvyw71l_OKIChVmMA3d98gF7yJmrFP2S1yUf_RvD3aq2VMwzuccM_13AzcF5blnVc2AceziNY9QEoXuvum3pnRBooRpPidX1g7Oh3bxm6Jw1QN8o7KOQodZiBXHYPKkOgndUI6QxTzYpMvjecyebQ/file?dl=1# [following]
# ...

# %%
# !wget https://www.dropbox.com/sh/75v5ehq4cdg5g5g/AABqY-3fJSmSMafFIlJXRE-9a/Anomaly-Videos-Part-4.zip?dl=1
# Out:
# --2023-03-06 03:53:19--  https://www.dropbox.com/sh/75v5ehq4cdg5g5g/AABqY-3fJSmSMafFIlJXRE-9a/Anomaly-Videos-Part-4.zip?dl=1
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.3.18, 2620:100:601b:18::a27d:812
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.3.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /sh/dl/75v5ehq4cdg5g5g/AABqY-3fJSmSMafFIlJXRE-9a/Anomaly-Videos-Part-4.zip [following]
# --2023-03-06 03:53:19--  https://www.dropbox.com/sh/dl/75v5ehq4cdg5g5g/AABqY-3fJSmSMafFIlJXRE-9a/Anomaly-Videos-Part-4.zip
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://ucc7ea47fe3818649609de0c192f.dl.dropboxusercontent.com/cd/0/get/B3vA2R7eiTrgahdu-kIbBjsyFqs_IkFvAyyCEA2m2d3BBScwafQiawjbYSrgLAHb7ISviL0EuZcd2vd7iKxck5EmG2qIN5P6SUjIUrhiz__QUScaQm6ztqBcoHNdS951T2iwXTdxFET0OfqpHmuhkz13A8iaxtxLYaFwxGRP0v2W-w/file?dl=1# [following]
# ...

# %%
# !wget https://www.dropbox.com/sh/75v5ehq4cdg5g5g/AAD5w76F_SZLdBgxVdvko-z5a/UCF_Crimes-Train-Test-Split.zip?dl=1
# Out:
# --2023-03-06 03:57:43--  https://www.dropbox.com/sh/75v5ehq4cdg5g5g/AAD5w76F_SZLdBgxVdvko-z5a/UCF_Crimes-Train-Test-Split.zip?dl=1
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.3.18, 2620:100:601b:18::a27d:812
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.3.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /sh/dl/75v5ehq4cdg5g5g/AAD5w76F_SZLdBgxVdvko-z5a/UCF_Crimes-Train-Test-Split.zip [following]
# --2023-03-06 03:57:43--  https://www.dropbox.com/sh/dl/75v5ehq4cdg5g5g/AAD5w76F_SZLdBgxVdvko-z5a/UCF_Crimes-Train-Test-Split.zip
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://ucf6e3b231b18aff9a03899b8e97.dl.dropboxusercontent.com/cd/0/get/B3s06K0HtMay_F0QqecoKGocY08cBzjdqWmvlr5twfieso3SYtvAcVeFl2ql3TtJ0q8Gf2TegYVVT1Rxdd4VT7LK_wrxOmmHV3-VLOfpXVX3LlMdupbSDDx8NUaeqR6nPCE9LbHOvp9tdyLQuhu4yeIaKO5gqQbrgU2cPf8z5quFRw/file?dl=1# [following]
# ...

# %%
# !unzip /content/UCF_Crimes-Train-Test-Split.zip?dl=1
# Out:
# Archive:  /content/UCF_Crimes-Train-Test-Split.zip?dl=1
#    creating: Action_Regnition_splits/
#   inflating: Action_Regnition_splits/train_003.txt
#   inflating: Action_Regnition_splits/test_001.txt
#   inflating: Action_Regnition_splits/train_002.txt
#   inflating: Action_Regnition_splits/test_004.txt
#   inflating: Action_Regnition_splits/train_001.txt
#   inflating: Action_Regnition_splits/test_003.txt
#   inflating: Action_Regnition_splits/ClassIDs.txt
#   inflating: Action_Regnition_splits/train_004.txt
#   inflating: Action_Regnition_splits/test_002.txt
#    creating: Anomaly_Detection_splits/
#   inflating: Anomaly_Detection_splits/Anomaly_Test.txt
#  extracting: Anomaly_Detection_splits/Anomaly_Train.txt

# %%
# !unzip /content/Anomaly-Videos-Part-1.zip?dl=1 -d /content/Anomaly

# %%
# !unzip /content/Anomaly-Videos-Part-2.zip?dl=1 -d /content/Anomaly

# %%
# !unzip /content/Anomaly-Videos-Part-3.zip?dl=1 -d /content/Anomaly
# Out:
# Archive:  /content/Anomaly-Videos-Part-3.zip?dl=1
#    creating: /content/Anomaly/Anomaly-Videos-Part-3/
#    creating: /content/Anomaly/Anomaly-Videos-Part-3/Robbery/
#   inflating: /content/Anomaly/Anomaly-Videos-Part-3/Robbery/Robbery028_x264.mp4
#   inflating: /content/Anomaly/Anomaly-Videos-Part-3/Robbery/Robbery036_x264.mp4
#   inflating: /content/Anomaly/Anomaly-Videos-Part-3/Robbery/Robbery077_x264.mp4
#   inflating: /content/Anomaly/Anomaly-Videos-Part-3/Robbery/Robbery082_x264.mp4
#   inflating: /content/Anomaly/Anomaly-Videos-Part-3/Robbery/Robbery029_x264.mp4
#   inflating: /content/Anomaly/Anomaly-Videos-Part-3/Robbery/Robbery110_x264.mp4
#   inflating: /content/Anomaly/Anomaly-Videos-Part-3/Robbery/Robbery084_x264.mp4
#   inflating: /content/Anomaly/Anomaly-Videos-Part-3/Robbery/Robbery023_x264.mp4
#   inflating: /content/Anomaly/Anomaly-Videos-Part-3/Robbery/Robbery103_x264.mp4
#   inflating: /content/Anomaly/Anomaly-Videos-Part-3/Robbery/Robbery064_x264.mp4
# ...

# %%
# !unzip /content/Anomaly-Videos-Part-4.zip?dl=1 -d /content/Anomaly
# Out:
# Archive:  /content/Anomaly-Videos-Part-4.zip?dl=1
#    creating: /content/Anomaly/Anomaly-Videos-Part-4/
#    creating: /content/Anomaly/Anomaly-Videos-Part-4/Vandalism/
#   inflating: /content/Anomaly/Anomaly-Videos-Part-4/Vandalism/Vandalism047_x264.mp4
#   inflating: /content/Anomaly/Anomaly-Videos-Part-4/Vandalism/Vandalism025_x264.mp4
#   inflating: /content/Anomaly/Anomaly-Videos-Part-4/Vandalism/Vandalism040_x264.mp4
#   inflating: /content/Anomaly/Anomaly-Videos-Part-4/Vandalism/Vandalism039_x264.mp4
#   inflating: /content/Anomaly/Anomaly-Videos-Part-4/Vandalism/Vandalism012_x264.mp4
#   inflating: /content/Anomaly/Anomaly-Videos-Part-4/Vandalism/Vandalism033_x264.mp4
#   inflating: /content/Anomaly/Anomaly-Videos-Part-4/Vandalism/Vandalism004_x264.mp4
#   inflating: /content/Anomaly/Anomaly-Videos-Part-4/Vandalism/Vandalism029_x264.mp4
#   inflating: /content/Anomaly/Anomaly-Videos-Part-4/Vandalism/Vandalism042_x264.mp4
# ...

# %%
import tensorflow as tf
import numpy as np
import os
import glob
import cv2
from sklearn.model_selection import train_test_split

data_dir = '/content/Anomaly'

crime_categories = ['Abuse', 'Arrest', 'Arson', 'Assault', 'RoadAccidents', 'Burglary', 'Explosion', 'Fighting', 'Robbery', 'Shooting', 'Stealing', 'Shoplifting', 'Vandalism']

# %%
video_files = glob.glob(os.path.join(data_dir, '*', '*.mp4'))

# %%
label_map = {category: label for label, category in enumerate(crime_categories)}
label_map
# Out:
# {'Abuse': 0,
#  'Arrest': 1,
#  'Arson': 2,
#  'Assault': 3,
#  'RoadAccidents': 4,
#  'Burglary': 5,
#  'Explosion': 6,
#  'Fighting': 7,
#  'Robbery': 8,
#  'Shooting': 9,
#  'Stealing': 10,
#  'Shoplifting': 11,
#  'Vandalism': 12}

# %%
def extract_frames(video_path):
    frames = []
    cap = cv2.VideoCapture(video_path)
    while cap.isOpened():
        ret, frame = cap.read()
        if ret:
            frame = cv2.resize(frame, (img_width, img_height))
            frames.append(frame)
        else:
            break
    cap.release()
    return np.array(frames)
extract_frames('/content/Anomaly/Burglary/Burglary051_x264.mp4')

# %%
def load_dataset(data_dir, batch_size, img_height, img_width, validation_split=0.2, shuffle=True, seed=42):
    # Get the list of all video files in the dataset folder
    video_files = glob.glob(os.path.join(data_dir, '*', '*.mp4'))

    # Create a dictionary mapping each crime category to a unique integer label
    label_map = {category: label for label, category in enumerate(crime_categories)}

    # Get the labels for all video files
    labels = [label_map[os.path.basename(os.path.dirname(video_file))] for video_file in video_files]

    # Split the video files into training and validation sets stratified by labels
    train_files, val_files, train_labels, val_labels = train_test_split(video_files, labels, test_size=validation_split, stratify=labels, random_state=seed)

    # Define the function to extract frames from each video
    # def extract_frames(video_path):
    #     frames = []
    #     cap = cv2.VideoCapture(video_path)
    #     while cap.isOpened():
    #         ret, frame = cap.read()
    #         if ret:
    #             frame = cv2.resize(frame, (img_width, img_height))
    #             frames.append(frame)
    #         else:
    #             break
    #     cap.release()
    #     return np.array(frames)
    def parse_video(video_file):
        # print(video_file)
    # Load the video using OpenCV
        try:
            cap = cv2.VideoCapture(video_file)
        except:
            print("error",video_file)

        # Extract frames from the video
        frames = []
        while True:
            ret, frame = cap.read()
            if not ret:
                break
            frame = cv2.resize(frame, (224, 224))
            frames.append(frame)
        cap.release()

        # Convert the frames to a numpy array and normalize pixel values
        frames = np.array(frames, dtype=np.float32)
        frames /= 255.0
        print(frames)
        return frames

    def parse_video_wrapper(video_file, label):
        frames = tf.numpy_function(parse_video, [video_file], tf.float32)
        return frames, label

    # Create TensorFlow datasets for training and validation sets
    train_dataset = tf.data.Dataset.from_tensor_slices((train_files, train_labels))
    train_dataset = train_dataset.shuffle(len(train_files))
    # train_dataset = train_dataset.map(lambda x, y: (tf.py_function(extract_frames, [x], tf.float32), y))
    train_dataset = train_dataset.map(parse_video_wrapper)
    train_dataset = train_dataset.batch(batch_size)
    train_dataset = train_dataset.prefetch(tf.data.AUTOTUNE)

    val_dataset = tf.data.Dataset.from_tensor_slices((val_files, val_labels))
    val_dataset = val_dataset.shuffle(len(val_files))
    val_dataset = val_dataset.map(lambda x, y: (tf.py_function(extract_frames, [x], tf.float32), y))
    val_dataset = val_dataset.batch(batch_size)
    val_dataset = val_dataset.prefetch(tf.data.AUTOTUNE)

    return train_dataset, val_dataset

# %%
batch_size = 32
img_height = 224
img_width = 224
validation_split = 0.2

train_dataset, val_dataset = load_dataset(data_dir, batch_size, img_height, img_width, validation_split)

# %%
BATCH_SIZE = 32
AUTO = tf.data.AUTOTUNE
INPUT_SHAPE = (28, 28, 28, 1)
NUM_CLASSES = 11

# OPTIMIZER
LEARNING_RATE = 1e-4
WEIGHT_DECAY = 1e-5

# TRAINING
EPOCHS = 20

# TUBELET EMBEDDING
PATCH_SIZE = (8, 8, 8)
NUM_PATCHES = (INPUT_SHAPE[0] // PATCH_SIZE[0]) ** 2

# ViViT ARCHITECTURE
LAYER_NORM_EPS = 1e-6
PROJECTION_DIM = 128
NUM_HEADS = 8
NUM_LAYERS = 8

# %%
from tensorflow import keras
from tensorflow.keras import layers

class PositionalEncoder(layers.Layer):
    def __init__(self, embed_dim, **kwargs):
        super().__init__(**kwargs)
        self.embed_dim = embed_dim

    def build(self, input_shape):
        _, num_tokens, _ = input_shape
        self.position_embedding = layers.Embedding(
            input_dim=num_tokens, output_dim=self.embed_dim
        )
        self.positions = tf.range(start=0, limit=num_tokens, delta=1)

    def call(self, encoded_tokens):
        # Encode the positions and add it to the encoded tokens
        encoded_positions = self.position_embedding(self.positions)
        encoded_tokens = encoded_tokens + encoded_positions
        return encoded_tokens

# %%
class TubeletEmbedding(layers.Layer):
    def __init__(self, embed_dim, patch_size, **kwargs):
        super().__init__(**kwargs)
        self.projection = layers.Conv3D(
            filters=embed_dim,
            kernel_size=patch_size,
            strides=patch_size,
            padding="VALID",
        )
        self.flatten = layers.Reshape(target_shape=(-1, embed_dim))

    def call(self, videos):
        projected_patches = self.projection(videos)
        flattened_patches = self.flatten(projected_patches)
        return flattened_patches

# %%
def create_vivit_classifier(
    tubelet_embedder,
    positional_encoder,
    input_shape=INPUT_SHAPE,
    transformer_layers=NUM_LAYERS,
    num_heads=NUM_HEADS,
    embed_dim=PROJECTION_DIM,
    layer_norm_eps=LAYER_NORM_EPS,
    num_classes=NUM_CLASSES,
):
    # Get the input layer
    inputs = layers.Input(shape=input_shape)
    # Create patches.
    patches = tubelet_embedder(inputs)
    # Encode patches.
    encoded_patches = positional_encoder(patches)

    # Create multiple layers of the Transformer block.
    for _ in range(transformer_layers):
        # Layer normalization and MHSA
        x1 = layers.LayerNormalization(epsilon=1e-6)(encoded_patches)
        attention_output = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=embed_dim // num_heads, dropout=0.1
        )(x1, x1)

        # Skip connection
        x2 = layers.Add()([attention_output, encoded_patches])

        # Layer Normalization and MLP
        x3 = layers.LayerNormalization(epsilon=1e-6)(x2)
        x3 = keras.Sequential(
            [
                layers.Dense(units=embed_dim * 4, activation=tf.nn.gelu),
                layers.Dense(units=embed_dim, activation=tf.nn.gelu),
            ]
        )(x3)

        # Skip connection
        encoded_patches = layers.Add()([x3, x2])

    # Layer normalization and Global average pooling.
    representation = layers.LayerNormalization(epsilon=layer_norm_eps)(encoded_patches)
    representation = layers.GlobalAvgPool1D()(representation)

    # Classify outputs.
    outputs = layers.Dense(units=num_classes, activation="softmax")(representation)

    # Create the Keras model.
    model = keras.Model(inputs=inputs, outputs=outputs)
    return model

# %%
def run_experiment():
    # Initialize model
    model = create_vivit_classifier(
        tubelet_embedder=TubeletEmbedding(
            embed_dim=PROJECTION_DIM, patch_size=PATCH_SIZE
        ),
        positional_encoder=PositionalEncoder(embed_dim=PROJECTION_DIM),
    )

    # Compile the model with the optimizer, loss function
    # and the metrics.
    optimizer = keras.optimizers.Adam(learning_rate=LEARNING_RATE)
    model.compile(
        optimizer=optimizer,
        loss="sparse_categorical_crossentropy",
        metrics=[
            keras.metrics.SparseCategoricalAccuracy(name="accuracy"),
            keras.metrics.SparseTopKCategoricalAccuracy(5, name="top-5-accuracy"),
        ],
    )

    # Train the model.
    _ = model.fit(train_dataset, epochs=EPOCHS, validation_data=val_dataset)

    _, accuracy, top_5_accuracy = model.evaluate(val_dataset)
    print(f"Test accuracy: {round(accuracy * 100, 2)}%")
    print(f"Test top 5 accuracy: {round(top_5_accuracy * 100, 2)}%")

    return model


model = run_experiment()
# Out:
# Epoch 1/20
# error b'/content/Anomaly/RoadAccidents/RoadAccidents149_x264.mp4'
# error b'/content/Anomaly/Fighting/Fighting010_x264.mp4'
# error b'/content/Anomaly/Arrest/Arrest022_x264.mp4'
# error b'/content/Anomaly/Fighting/Fighting005_x264.mp4'
# ---------------------------------------------------------------------------
# UnknownError                              Traceback (most recent call last)
# <ipython-input-82-c922cf472fdc> in <module>
#      30
#      31
# ---> 32 model = run_experiment()
#
# <ipython-input-82-c922cf472fdc> in run_experiment()
#      21
#      22     # Train the model.
# ---> 23     _ = model.fit(train_dataset, epochs=EPOCHS, validation_data=val_dataset)
#      24
#      25     _, accuracy, top_5_accuracy = model.evaluate(val_dataset)
#
# /usr/local/lib/python3.8/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
# ...
